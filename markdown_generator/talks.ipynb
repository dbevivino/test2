# %% [markdown]
# # Talks markdown generator for academicpages
#
# Takes a TSV of talks with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `talks.py`. Run either from the `markdown_generator` folder after replacing `talks.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases, rather than Stuart's non-standard TSV format and citation style.

# %%
import pandas as pd
import os

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: title, type, url_slug, venue, date, location, talk_url, description, with a header at the top. Many of these fields can be blank, but the columns must be in the TSV.
#
# - Fields that cannot be blank: `title`, `url_slug`, `date`. All else can be blank. `type` defaults to "Talk"
# - `date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper.
#     - The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/talks/YYYY-MM-DD-[url_slug]`
#     - The combination of `url_slug` and `date` must be unique, as it will be the basis for your filenames
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat talks.tsv
# Out:
# title	category	type	url_slug	venue	date	location	talk_url	description	coauthors	citation
# Priming boundaries in production: Data from French	talks	Conference talk	bevivino-SP-2024	Speech Prosody 2024 (SP2024)	2024-07-05	Leiden, The Netherlands 			M. Huygevelde, G. Turco & B. Hemforth	<strong>Bevivino, D.</strong>, Huygevelde, M., Hemforth, B., & Turco, G. (2024, July 5). Priming boundaries in production: Data from French. <em>12th International Conference on Speech Prosody. Special Session on Advances in studies on prosodic planning</em>. Leiden, The Netherlands. [Talk & <a href="https://www.isca-archive.org/speechprosody_2024/bevivino24_speechprosody.html">Proceedings paper</a>]
# Priming prosodic boundaries across constructions 	talks	Conference talk	bevivino-LE-2022	Linguistic Evidence 2022	2022-10-06	Paris, France			G. Turco & B. Hemforth	<strong>Bevivino, D.</strong>, Turco, G., & Hemforth, B. (2022, October 6). Priming prosodic boundaries across constructions. <em>Linguistic Evidence Conference</em>. Paris, France. [Talk & <a href="https://cnrs.hal.science/hal-03924619/document">Conference paper</a>]
# Attention and labelling in monolingual and bilingual caregiver-infant interactions	talks	Conference talk (delivered by MK)	bevivino-ICIS-2022	the International Congress of Infant Studies (ICIS)	2022-07-09	Ottawa, Canada 			M. Kalashnikova & L. Singh	Kalashnikova, M., <strong>Bevivino, D.</strong>, & Singh, L. (2022, July 9). Attention and labelling in monolingual and bilingual caregiver-infant interactions. <em>International Congress of Infant Studies (ICIS)</em>. Ottawa, Canada. [Talk delivered by MK &  <a href="https://infantstudies.org/wp-content/uploads/2022/07/ICIS-2022-Abstract-ProceedingsJuly07.pdf#page=76">Abstract</a>]
# Caregivers adjust their speech in response to bilingual infants’ attentional preferences 	talks	Conference talk	bevivino-ABC-2021	ABC'21: Language and cognition in typical and atypical development at the Chinese University of Hong Kong	2021-12-04	Hong Kong/Virtual			L. Singh & M. Kalashnikova	<strong>Bevivino, D.</strong>, Singh, L., & Kalashnikova, M. (2021, December 4). Caregivers adjust their speech in response to bilingual infants' attentional preferences. <em>ABC'21 Conference: Language and cognition in typical and atypical development</em>. The Chinese University of Hong Kong/Virtual.
# Priming cooperating prosodic phrasing increases reading times: An eye-tracking study	posters	Poster presentation	bevivino-amlap-2025	Architectures and Mechanisms for Language Processing (AMLaP 31) 	2025-09-04	Prague, Czechia			B. Hemforth & G. Turco	<strong>Bevivino, D.</strong>, Hemforth, B., & Turco, G. (2025, Sept. 4). Priming cooperating prosodic phrasing increases reading times: An eye-tracking study. <em>Architectures and Mechanisms for Language Processing (AMLaP 31)</em>. Prague, Czechia. [<a href="https://drive.google.com/file/d/1HApG5mfw5M327wXHzSMFAK1S-K8QMZVE/view?usp=sharing">Poster</a> & <a href="https://amlap2025.ff.cuni.cz/wp-content/uploads/sites/131/2025/09/AMLAP_book_of_abstracts.pdf#page=327">Abstract</a>]
# Does priming prosodic phrasing modulate reading times? Evidence from audio-primed acceptability judgment experiments	posters	Poster presentation	bevivino-amlap-2023	Architectures and Mechanisms for Language Processing (AMLaP 29)	2023-09-02	Donostia-San Sebastián, Basque Country, Spain			G. Turco & B. Hemforth	<strong>Bevivino, D.</strong>, Turco, G., & Hemforth, B. (2023, Sept. 2). Does priming prosodic phrasing modulate reading times? Evidence from audio-primed acceptability judgment experiments. <em>Architectures and Mechanisms for Language Processing (AMLaP 29)</em>. Donostia-San Sebastían, Basque Country, Spain. [<a href="https://drive.google.com/file/d/1LwfH2QShIuDlz4T5dRptvIFGUrqLDO_h/view?usp=sharing">Poster</a>]
# Data from online production experiments and challenges for collecting good-quality recordings for prosodic analyses	posters	Poster presentation	bevivino-ICPhS-2023	the International Congress of Phonetic Sciences (ICPhS 20) 	2023-08-10	Prague, Czechia			B. Hemforth & G. Turco	<strong>Bevivino, D.</strong>, Hemforth, B., & Turco, G. (2023, August 10). Data from online production experiments and challenges for collecting good-quality recordings for prosodic analyses. <em>20th International Congress of Phonetic Sciences (ICPhS 2023)</em>. Prague, Czechia. [<a href="https://drive.google.com/file/d/1xhL6D6uOU-dPWHvULJoRMxSmIqV2OkQG/view?usp=drivesdk">Poster</a> & <a href="https://www.internationalphoneticassociation.org/icphs-proceedings/ICPhS2023/full_papers/152.pdf">Proceedings paper</a>]
# Priming prosodic boundaries in an online speech production experiment	posters	Poster presentation	bevivino-amlap-2022	Architectures and Mechanisms for Language Processing (AMLaP 28) 	2022-09-07	York, UK			B. Hemforth & G. Turco	<strong>Bevivino, D.</strong>, Hemforth, B., & Turco, G. (2022, September 7). Priming prosodic boundaries in an online speech production experiment. <em>Architectures and Mechanisms for Language Processing (AMLaP 28)</em>. York, UK. [<a href="https://cnrs.hal.science/hal-03924672/document">Poster</a>]
# Eye-tracking Workshop	invited	Invited tutorial	bevivino-RJCP-2025	Rencontres Jeunes Chercheurs en Parole (RJCP)	2025-11-05	Paris, France			M. Foegel	<strong>Bevivino, D. </strong> & Foegel, Martial (2025, November 5). Eye-tracking Workshop. To be delivered at <em>Rencontres Jeunes Chercheurs en Parole (RJCP)</em>. Paris, France.
# Does priming prosodic phrasing modulate sentence processing? An eye-tracking study design	invited	Internal presentation	bevivino-XL-2023	the Experimental Linguistics Workshop 	2023-09-08	Paris, France				<strong>Bevivino, D. </strong>(2023, September 8). Does priming prosodic phrase modulate sentence processing? An eye-tracking study design. <em>Experimental Linguistic Workshop</em>. Paris, France.
# Priming prosodic structure in production in English: A pilot study	invited	Invited talk	bevivino-Labex-2022	the Laboratory of Excellence “Empirical Foundations of Linguistics” (LabEx EFL) Annual Symposium 	2022-06-16	Paris, France				<strong>Bevivino, D</strong>., Turco, G., & Hemforth, B. (2022, June 16). Priming prosodic structure in production in English: A pilot study. <em>Laboratory of Excellence "Empirical Foundations of Linguistics" (LabEx EFL) Annual Symposium</em>. Paris, France.
# A cross-linguistic and acquisitional perspective on prosodic priming 	invited	Internal presentation	bevivino-SFL-2023	the PhD's seminar SFL-LLF 	2022-01-17	Paris, France				<strong>Bevivino, D. </strong>(2022, January 17). A cross-linguistic and acquisitional perspective on prosodic priming. <em>PhD's seminar SFL-LLF</em>. Paris, France.
# Does priming prosodic phrasing modulate sentence processing? An eye-tracking study 	schools	Poster	bevivino-MPI-2024	MEDAL Summer School in Experimental Linguistics at the Max Planck Institute for Psycholinguistics	2024-06-18	Nijmegen, The Netherlands				<strong>Bevivino, D.</strong>, Turco, G., & Hemforth, B. (2024, June 18). Does priming prosodic phrasing modulate sentence processing? An Eye-Tracking Study. <em>2024 MEDAL Summer School in Experimental Linguistics</em>. Max Planck Institute for Psycholinguistics, Nijmegen, The Netherlands. [<a href="https://drive.google.com/file/d/1hbw9SCerEI3u-isu1d77nYIEazExWVZa/view?usp=sharing">Poster</a>]
# Breaking the French Accentual Phrase: Does priming prosodic phrasing modulate sentence processing? 	schools	Poster	bevivino-LSA-2023	the LSA Summer Institute at Umass	2023-07-12	Amherst (MA), USA				<strong>Bevivino, D.</strong>, Turco, G., & Hemforth, B. (2023, July 12). Breaking the French accentual phrase: Does priming prosodic phrasing modulate sentence processing? <em>2023 Linguistic Society of America Summer Institute</em>. UMass, Amherst (MA), USA. [<a href="https://drive.google.com/file/d/1hbw9SCerEI3u-isu1d77nYIEazExWVZa/view?usp=sharing">Poster</a>]

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
talks = pd.read_csv("talks.tsv", sep="\t", header=0)
talks
# Out:
#                                                 title category  \
# 0   Priming boundaries in production: Data from Fr...    talks
# 1   Priming prosodic boundaries across constructions     talks
# 2   Attention and labelling in monolingual and bil...    talks
# 3   Caregivers adjust their speech in response to ...    talks
# 4   Priming cooperating prosodic phrasing increase...  posters
# 5   Does priming prosodic phrasing modulate readin...  posters
# 6   Data from online production experiments and ch...  posters
# 7   Priming prosodic boundaries in an online speec...  posters
# 8                               Eye-tracking Workshop  invited
# 9   Does priming prosodic phrasing modulate senten...  invited
# 10  Priming prosodic structure in production in En...  invited
# 11  A cross-linguistic and acquisitional perspecti...  invited
# 12  Does priming prosodic phrasing modulate senten...  schools
# 13  Breaking the French Accentual Phrase: Does pri...  schools
#
#                                  type             url_slug  \
# 0                     Conference talk     bevivino-SP-2024
# 1                     Conference talk     bevivino-LE-2022
# 2   Conference talk (delivered by MK)   bevivino-ICIS-2022
# 3                     Conference talk    bevivino-ABC-2021
# 4                 Poster presentation  bevivino-amlap-2025
# 5                 Poster presentation  bevivino-amlap-2023
# 6                 Poster presentation  bevivino-ICPhS-2023
# 7                 Poster presentation  bevivino-amlap-2022
# 8                    Invited tutorial   bevivino-RJCP-2025
# 9               Internal presentation     bevivino-XL-2023
# 10                       Invited talk  bevivino-Labex-2022
# 11              Internal presentation    bevivino-SFL-2023
# 12                             Poster    bevivino-MPI-2024
# 13                             Poster    bevivino-LSA-2023
#
#                                                 venue        date  \
# 0                        Speech Prosody 2024 (SP2024)  2024-07-05
# 1                            Linguistic Evidence 2022  2022-10-06
# 2   the International Congress of Infant Studies (...  2022-07-09
# 3   ABC'21: Language and cognition in typical and ...  2021-12-04
# 4   Architectures and Mechanisms for Language Proc...  2025-09-04
# 5   Architectures and Mechanisms for Language Proc...  2023-09-02
# 6   the International Congress of Phonetic Science...  2023-08-10
# 7   Architectures and Mechanisms for Language Proc...  2022-09-07
# 8       Rencontres Jeunes Chercheurs en Parole (RJCP)  2025-11-05
# 9              the Experimental Linguistics Workshop   2023-09-08
# 10  the Laboratory of Excellence “Empirical Founda...  2022-06-16
# 11                         the PhD's seminar SFL-LLF   2022-01-17
# 12  MEDAL Summer School in Experimental Linguistic...  2024-06-18
# 13                  the LSA Summer Institute at Umass  2023-07-12
#
#                                          location  talk_url  description  \
# 0                        Leiden, The Netherlands        NaN          NaN
# 1                                   Paris, France       NaN          NaN
# 2                                 Ottawa, Canada        NaN          NaN
# 3                               Hong Kong/Virtual       NaN          NaN
# 4                                 Prague, Czechia       NaN          NaN
# 5   Donostia-San Sebastián, Basque Country, Spain       NaN          NaN
# 6                                 Prague, Czechia       NaN          NaN
# 7                                        York, UK       NaN          NaN
# 8                                   Paris, France       NaN          NaN
# 9                                   Paris, France       NaN          NaN
# 10                                  Paris, France       NaN          NaN
# 11                                  Paris, France       NaN          NaN
# 12                      Nijmegen, The Netherlands       NaN          NaN
# 13                              Amherst (MA), USA       NaN          NaN
#
#                                 coauthors  \
# 0   M. Huygevelde, G. Turco & B. Hemforth
# 1                  G. Turco & B. Hemforth
# 2              M. Kalashnikova & L. Singh
# 3              L. Singh & M. Kalashnikova
# 4                  B. Hemforth & G. Turco
# 5                  G. Turco & B. Hemforth
# 6                  B. Hemforth & G. Turco
# 7                  B. Hemforth & G. Turco
# 8                               M. Foegel
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
#
#                                              citation
# 0   <strong>Bevivino, D.</strong>, Huygevelde, M.,...
# 1   <strong>Bevivino, D.</strong>, Turco, G., & He...
# 2   Kalashnikova, M., <strong>Bevivino, D.</strong...
# 3   <strong>Bevivino, D.</strong>, Singh, L., & Ka...
# 4   <strong>Bevivino, D.</strong>, Hemforth, B., &...
# 5   <strong>Bevivino, D.</strong>, Turco, G., & He...
# 6   <strong>Bevivino, D.</strong>, Hemforth, B., &...
# 7   <strong>Bevivino, D.</strong>, Hemforth, B., &...
# 8   <strong>Bevivino, D. </strong> & Foegel, Marti...
# 9   <strong>Bevivino, D. </strong>(2023, September...
# 10  <strong>Bevivino, D</strong>., Turco, G., & He...
# 11  <strong>Bevivino, D. </strong>(2022, January 1...
# 12  <strong>Bevivino, D.</strong>, Turco, G., & He...
# 13  <strong>Bevivino, D.</strong>, Turco, G., & He...

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;",
    "–": "&ndash;"
    }

def html_escape(text):
    if type(text) is str:
        return "".join(html_escape_table.get(c,c) for c in text)
    else:
        return "False"

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
loc_dict = {}

for row, item in talks.iterrows():
    
    md_filename = str(item.date) + "-" + item.url_slug + ".md"
    html_filename = str(item.date) + "-" + item.url_slug 
    year = item.date[:4]
    
    md = "---\ntitle: \""   + item.title + '"\n'
    md += "collection: talks" + "\n"
    
    if len(str(item.type)) > 3:
        md += 'type: "' + item.type + '"\n'
    else:
        md += 'type: "Talk"\n'
    
    md += "permalink: /talks/" + html_filename + "\n"
    
    if len(str(item.venue)) > 3:
        md += 'venue: "' + item.venue + '"\n'
        
    if len(str(item.location)) > 3:
        md += "date: " + str(item.date) + "\n"
    
    if len(str(item.location)) > 3:
        md += 'location: "' + str(item.location) + '"\n'
    
    # ADD CITATION and coauthors
    md += "\ncitation: '" + html_escape(item.citation) + "'"
    md += "\ncoauthors: '" + html_escape(item.coauthors) + "'"
    
    # MINIMAL ADDITION: add category if it exists
    if len(str(item.category)) > 0 and str(item.category) != 'nan':
        md += "\ncategory: " + str(item['category'])
    
    # close it
    md += "\n---"
    
    
    if len(str(item.talk_url)) > 3:
        md += "\n[More information here](" + item.talk_url + ")\n" 
        
    
    if len(str(item.description)) > 3:
        md += "\n" + html_escape(item.description) + "\n"
        
        
    md_filename = os.path.basename(md_filename)
    #print(md)
    
    with open("../_talks/" + md_filename, 'w') as f:
        f.write(md)

# %% [markdown]
# These files are in the talks directory, one directory below where we're working from.

# %%
# !ls ../_talks
# Out:
# 2012-example-output.md		   2023-08-10-bevivino-ICPhS-2023.md
# 2021-12-04-bevivino-ABC-2021.md    2023-09-02-bevivino-amlap-2023.md
# 2022-01-17-bevivino-SFL-2023.md    2023-09-08-bevivino-XL-2023.md
# 2022-06-16-bevivino-Labex-2022.md  2024-06-18-bevivino-MPI-2024.md
# 2022-07-09-bevivino-ICIS-2022.md   2024-07-05-bevivino-SP-2024.md
# 2022-09-07-bevivino-amlap-2022.md  2025-09-04-bevivino-amlap-2025.md
# 2022-10-06-bevivino-LE-2022.md	   2025-11-05-bevivino-RJCP-2025.md
# 2023-07-12-bevivino-LSA-2023.md

# %%
# !cat ../_talks/2013-03-01-tutorial-1.md
# Out:
# cat: ../_talks/2013-03-01-tutorial-1.md: No such file or directory
